# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
from src import funcion10

# %%
rounds = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]

# %%
puntos_jugadores = {
'Shadow': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp' : 0, 'puntos' : 0},
'Blaze': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp' : 0, 'puntos' : 0},
'Viper': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp' : 0, 'puntos' : 0},
'Frost': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp' : 0, 'puntos' : 0},
'Reaper': {'kills': 0, 'assists': 0, 'deaths': 0, 'mvp' : 0, 'puntos' : 0}
}

# %%
#recorro la Lista por sus Elementos (rondas)
i = 1
for round in rounds :
     print(f"ranking ronda {i} : \nPlayer    Kills   Assists    Deaths")
     max_points = 0
     mvp = ""
     #Recorro cada elemento(Rondas) del diccionario {jugador : actions}
     for jugador, actions in round.items() :
              
         #recorro el diccionario de los jugadores {action : cantidad}
         point = funcion10.sumar_actions(jugador, actions, puntos_jugadores) #sumo acciones (kills, assists, deaths) y modifico PuntosTotales

         if ( point > max_points) : #Hay Mejor Puntaje
             max_points = point
             mvp = jugador
         funcion10.imprimir_ronda(jugador, actions)

     i += 1
     puntos_jugadores[mvp]["mvp"] += 1 #guardo MVP
     print(f"\nMVP de esta ronda es {mvp}\n")
funcion10.imprimir_resultado_final(puntos_jugadores)
# Out:
# ranking ronda 1 :
# Player    Kills   Assists    Deaths
# Shadow       2       1       True
# Blaze       1       0       False
# Viper       1       2       True
# Frost       0       1       False
# Reaper       1       1       False
#
# MVP de esta ronda es Shadow
#
# ranking ronda 2 :
# Player    Kills   Assists    Deaths
# Shadow       0       2       False
# Blaze       2       0       True
# Viper       1       1       False
# Frost       2       1       True
# Reaper       0       1       False
#
# MVP de esta ronda es Frost
#
# ranking ronda 3 :
# Player    Kills   Assists    Deaths
# Shadow       1       0       False
# Blaze       2       2       True
# Viper       1       1       True
# Frost       0       1       False
# Reaper       1       1       False
#
# MVP de esta ronda es Blaze
#
# ranking ronda 4 :
# Player    Kills   Assists    Deaths
# Shadow       2       1       False
# Blaze       1       0       True
# Viper       0       2       False
# ...
